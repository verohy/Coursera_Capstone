# %% [markdown]
# # Notebook: Showing Citizens Hospitals Distribution along Toronto and its Boroughs

# %% [markdown]
# ### February 9, 2021

# %% [markdown]
# ## Introduction

# %% [markdown]
# The project: "Showing Citizens Hospitals Distribution along Toronto and its boroughs" aims to be a friendly way to inform people where hospitals are across the most populated city of Canada according to the national Census of 2016 and their ratings according to google review.
#
#
# The present document represents the Final Project for the IBM Data Science Certificate taught through Coursera Platform. It is requiered to use "Foursquare", "an independent location data platform for understanding how people move through the real world", according to the firm.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# The purpose of the project is to inform and empower regular citizens from the city of Toronto in the canadian province of Ontario or willing to live there, in a simple and graphical way so they can see how Hospitals are located and rated across the city and its boroughs.
#
# It is important to note that the proximity to a hospital does not necessary imply a better access to health assitance, but it can be a variable influencing the decisions on where to live, especially focusing on vulnerable population where this project may facilitate an informed decision of the user on which borough to choose.

# %% [markdown]
# ## Data, Packages and Tools

# %% [markdown]
# The data used is the names of the hospitals, their locations, ratings and capacity, measured by number of beds. It comes principally from the following sources:
#
# 1. Canada 2016 Census, for selecting the most populated city
# 2. Canadian Institute for Health Information (CIHI) for the hospitals located in the Health Region of "Toronto Central LHIN" and number of beds per hospital
# 3. Foursquare for Hospitals location
# 4. Google for Hospital location and rating
# 4. Several python packages for managing and showing data, as pandas, folium and geopy.
# 5. IBM Cloud Pak is the tool for running the code

# %% [markdown]
# #### Importing the libraries that will be used in the project

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

#conda install folium
# !pip install folium
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

print('Libraries imported.')
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Libraries imported.

# %% [markdown]
# #### Creating the data frame of the cities

# %%
address1 = 'Toronto, Ontario'
geolocator1 = Nominatim(user_agent="Toronto_explorer")
location1 = geolocator1.geocode(address1)
latitude1 = location1.latitude
longitude1 = location1.longitude
#print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude1, longitude1))

address2 = 'Montreal, Quebec'
geolocator2 = Nominatim(user_agent="Montreal_explorer")
location2 = geolocator2.geocode(address2)
latitude2 = location2.latitude
longitude2 = location2.longitude
#print('The geograpical coordinate of Montreal are {}, {}.'.format(latitude2, longitude2))

address3 = 'Calgary, Alberta'
geolocator3 = Nominatim(user_agent="Calgary_explorer")
location3 = geolocator3.geocode(address3)
latitude3 = location3.latitude
longitude3 = location3.longitude
#print('The geograpical coordinate of Calgary are {}, {}.'.format(latitude3, longitude3))

dfcanada = pd.DataFrame(np.array([["Toronto", "Ontario",2731571,latitude1,longitude1], ['Montreal','Quebec',1704694,latitude2,longitude2], ['Calgary','Alberta',1239220,latitude3,longitude3]]),
                   columns=['City', 'Province',"Population",'Latitude', 'Longitude'])
dfcanada
# Out:
#        City Province Population    Latitude     Longitude
# 0   Toronto  Ontario    2731571  43.6534817   -79.3839347
# 1  Montreal   Quebec    1704694  45.4972159   -73.6103642
# 2   Calgary  Alberta    1239220  51.0534234  -114.0625892

# %% [markdown]
# We can see that Toronto is the most populated city of Canada. As a second part of the project more cities can be added.

# %% [markdown]
# #### Generating Canadas map and marking the cities

# %%
# Map of Canada using latitude and longitude values
map_canada = folium.Map(location=[60.130, -110.35], zoom_start=4)

# add markers to map
for city, province, pop, lat, lng, in zip(dfcanada['City'], dfcanada['Province'], dfcanada['Population'], dfcanada['Latitude'], dfcanada['Longitude']):
    label = '{}, {}'.format(city, province)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color='turquoise',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_canada)  
    
map_canada
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b9de7dab57124a2a870aaadf6c4aa780%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b9de7dab57124a2a870aaadf6c4aa780%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b9de7dab57124a2a870aaadf6c4aa780%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b9de7dab57124a2a870aaadf6c4aa780%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B60.13%2C%20-110.35%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
#   If you are not able to see the map, you may find a picture of it in the following link: https://raw.githubusercontent.com/verohy/Coursera_Capstone/master/Canada%20Map.png

# %% [markdown]
# #### Using Foursquare API

# %%
#credentials for the Foursquare API
CLIENT_ID = 'KHLA0MRHSLCYLHZSLZAGPQX4QZL5NYKCFQSMRG2JAXUIWC2O' # your Foursquare ID
ACCESS_TOKEN = 'DR4VOEHRB3NBWSSFJ0NEOYB43MNJ1SVDO1DQCXJ4C3J1C0JU' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 200
print('Your CLIENT_ID is: ' + CLIENT_ID)
# Out:
# Your CLIENT_ID is: KHLA0MRHSLCYLHZSLZAGPQX4QZL5NYKCFQSMRG2JAXUIWC2O

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# #### Exercise using Toronto Data

# %%
search_query = 'Hospital'
radius = 500000
print(search_query + ' .... OK!')
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# Hospital .... OK!
# 'https://api.foursquare.com/v2/venues/search?client_id=KHLA0MRHSLCYLHZSLZAGPQX4QZL5NYKCFQSMRG2JAXUIWC2O&client_secret=LMFK1NJLDAGTPRSNPMHOOANCZ55WFZYWLISDH0NLUSAWBDDO&ll=43.6534817,-79.3839347&oauth_token=DR4VOEHRB3NBWSSFJ0NEOYB43MNJ1SVDO1DQCXJ4C3J1C0JU&v=20180604&query=Hospital&radius=500000&limit=200'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60234117051c9e6616584a49'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4ad4c064f964a5206ef820e3',
#     'name': 'The Hospital for Sick Children (SickKids)',
#     'location': {'address': '555 University Ave.',
#      'crossStreet': 'at Gerrard St.',
#      'lat': 43.657498668962646,
#      'lng': -79.3865121609307,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657498668962646,
#        'lng': -79.3865121609307}],
#      'distance': 492,
#      'postalCode': 'M5G 1X8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['555 University Ave. (at Gerrard St.)',
#       'Toronto ON M5G 1X8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ad4c064f964a5206ff820e3',
#     'name': "St. Michael's Hospital",
#     'location': {'address': '30 Bond St',
#      'crossStreet': 'at Queen St E',
#      'lat': 43.65378419391942,
#      'lng': -79.37780857086182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65378419391942,
#        'lng': -79.37780857086182}],
#      'distance': 494,
#      'postalCode': 'M5B 1W8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Bond St (at Queen St E)',
#       'Toronto ON M5B 1W8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ad4c064f964a52070f820e3',
#     'name': 'Toronto General Hospital',
#     'location': {'address': '190 Elizabeth St',
#      'crossStreet': 'at Gerrard St W',
#      'lat': 43.658762182159144,
#      'lng': -79.38829248908566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658762182159144,
#        'lng': -79.38829248908566}],
#      'distance': 684,
#      'postalCode': 'M5G 2C4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['190 Elizabeth St (at Gerrard St W)',
#       'Toronto ON M5G 2C4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4af0615cf964a5208cdb21e3',
#     'name': "Women's College Hospital",
#     'location': {'address': '76 Grenville St.',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.66149084521543,
#      'lng': -79.38760156543788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66149084521543,
#        'lng': -79.38760156543788}],
#      'distance': 939,
#      'postalCode': 'M5S 1B2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['76 Grenville St. (at Bay St.)',
#       'Toronto ON M5S 1B2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4e3dd18362e19d6109746a06',
#     'name': 'Toronto General Hospital Emergency Room',
#     'location': {'address': '190 Elizabeth St',
#      'crossStreet': 'at Gerrard St W',
#      'lat': 43.65842614181627,
#      'lng': -79.38646209755869,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65842614181627,
#        'lng': -79.38646209755869}],
#      'distance': 586,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['190 Elizabeth St (at Gerrard St W)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d194941735',
#       'name': 'Emergency Room',
#       'pluralName': 'Emergency Rooms',
#       'shortName': 'Emergency Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4b1fbe8af964a5209e2824e3',
#     'name': "Mount Sinai Hospital Women's and Infants' Department",
#     'location': {'address': '700 University Ave., 3rd floor, Ontario Power Generation Building',
#      'crossStreet': 'at College St.',
#      'lat': 43.6596121502049,
#      'lng': -79.39076121745926,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6596121502049,
#        'lng': -79.39076121745926}],
#      'distance': 876,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['700 University Ave., 3rd floor, Ontario Power Generation Building (at College St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4af2fb96f964a52086e921e3',
#     'name': 'Toronto Western Hospital',
#     'location': {'address': '399 Bathurst St.',
#      'crossStreet': 'at Dundas St. West',
#      'lat': 43.65343431584569,
#      'lng': -79.40607359183444,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65343431584569,
#        'lng': -79.40607359183444}],
#      'distance': 1783,
#      'postalCode': 'M5T 2S7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['399 Bathurst St. (at Dundas St. West)',
#       'Toronto ON M5T 2S7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ae9bd8af964a520feb521e3',
#     'name': 'Mount Sinai Hospital, Joseph and Wolf Lebovic Centre',
#     'location': {'address': '60 Murray St',
#      'crossStreet': 'College & University',
#      'lat': 43.65824708835551,
#      'lng': -79.39147285590467,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65824708835551,
#        'lng': -79.39147285590467}],
#      'distance': 806,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['60 Murray St (College & University)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4fd8e916e4b0a8dbd1d82589',
#     'name': 'Hospital Row',
#     'location': {'lat': 43.653938735433115,
#      'lng': -79.38081484586074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653938735433115,
#        'lng': -79.38081484586074}],
#      'distance': 256,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '58cc204f45005e5834b89895',
#     'name': 'Hospital',
#     'location': {'lat': 43.65319,
#      'lng': -79.37637,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65319,
#        'lng': -79.37637}],
#      'distance': 610,
#      'postalCode': 'M5C',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5C', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1b3941735',
#       'name': 'Medical School',
#       'pluralName': 'Medical Schools',
#       'shortName': 'Medical School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '530e123911d277e2ae95c564',
#     'name': 'Toronto General Hospital Parking Lot',
#     'location': {'address': 'Elizabeth Street',
#      'crossStreet': 'College & Elizabeth',
#      'lat': 43.65978,
#      'lng': -79.385699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65978,
#        'lng': -79.385699}],
#      'distance': 715,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Elizabeth Street (College & Elizabeth)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b44',
#       'name': 'Auto Garage',
#       'pluralName': 'Auto Garages',
#       'shortName': 'Auto Garage',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4bce159acc8cd13ac7b6c3cf',
#     'name': 'Dundas Euclid Animal Hospital',
#     'location': {'address': '840 Dundas St. W.',
#      'crossStreet': 'Euclid',
#      'lat': 43.65151776470952,
#      'lng': -79.40998382315287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65151776470952,
#        'lng': -79.40998382315287}],
#      'distance': 2109,
#      'postalCode': 'M6J 1V5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['840 Dundas St. W. (Euclid)',
#       'Toronto ON M6J 1V5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '59525287c4df1d49b8a1e677',
#     'name': "St Michael's Hospital - Gastroenterology",
#     'location': {'lat': 43.653653,
#      'lng': -79.378081,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653653,
#        'lng': -79.378081}],
#      'distance': 471,
#      'postalCode': 'M5B 1W8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5B 1W8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4c12aaf7a9c220a14d6a549d',
#     'name': 'Bay Cat & Bay Dog Hospital',
#     'location': {'address': '525 King E',
#      'crossStreet': 'Sumach',
#      'lat': 43.655346,
#      'lng': -79.35877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655346,
#        'lng': -79.35877}],
#      'distance': 2037,
#      'postalCode': 'M5A 1M3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['525 King E (Sumach)',
#       'Toronto ON M5A 1M3',
#       'Canada']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ec2d8502c5b1356c46f4248',
#     'name': "Starbucks (St. Michael's Hospital)",
#     'location': {'lat': 43.65619278670729,
#      'lng': -79.37884636582207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65619278670729,
#        'lng': -79.37884636582207}],
#      'distance': 508,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '5615508c498e81840497746b',
#     'name': "St. Michael's Hospital - Glaucoma & Nerve Protection",
#     'location': {'lat': 43.653703,
#      'lng': -79.37949,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653703,
#        'lng': -79.37949}],
#      'distance': 358,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '522e32fae4b09b556e370f19',
#       'name': 'Eye Doctor',
#       'pluralName': 'Eye Doctors',
#       'shortName': 'Eye Doctor',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4fca52d5e4b098b3ef28a713',
#     'name': "Inpatient Lounge - St. Michael's Hospital",
#     'location': {'lat': 43.653428,
#      'lng': -79.379383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653428,
#        'lng': -79.379383}],
#      'distance': 366,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ad4c064f964a52071f820e3',
#     'name': 'Mount Sinai Hospital',
#     'location': {'address': '600 University Ave',
#      'lat': 43.657701,
#      'lng': -79.389711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657701,
#        'lng': -79.389711}],
#      'distance': 661,
#      'postalCode': 'M5G 1X5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['600 University Ave',
#       'Toronto ON M5G 1X5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '52ab3cc6498e500543787648',
#     'name': 'MRI Department Sick Kids Hospital',
#     'location': {'address': '555 University Ave.',
#      'lat': 43.65714939590222,
#      'lng': -79.38432281548036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65714939590222,
#        'lng': -79.38432281548036}],
#      'distance': 409,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['555 University Ave.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ec6412182311ff83c5a9e9b',
#     'name': 'Rouge Valley Hospital',
#     'location': {'address': '580 Harwood Avenue Soith',
#      'lat': 43.6548432,
#      'lng': -79.379067,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6548432,
#        'lng': -79.379067}],
#      'distance': 420,
#      'cc': 'CA',
#      'city': 'Ajax',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['580 Harwood Avenue Soith', 'Ajax ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4f4e40c2e4b082dc5ca9f9cf',
#     'name': 'Endoscopy Unit St Michaels Hospital',
#     'location': {'lat': 43.65237139680637,
#      'lng': -79.37892334627455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65237139680637,
#        'lng': -79.37892334627455}],
#      'distance': 422,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4f09dee1e4b026656fae4626',
#     'name': "Gift Shop At St Michael's Hospital",
#     'location': {'crossStreet': 'Queen And Victoria',
#      'lat': 43.65394745632515,
#      'lng': -79.37848345711284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65394745632515,
#        'lng': -79.37848345711284}],
#      'distance': 442,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Queen And Victoria', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4e5e3506fa768fe5f2c3ecc1',
#     'name': 'St Michael Hospital',
#     'location': {'address': '50 Bond street',
#      'lat': 43.654023682719696,
#      'lng': -79.3787363936361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654023682719696,
#        'lng': -79.3787363936361}],
#      'distance': 423,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['50 Bond street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '50d32905498ec019e3c227cf',
#     'name': "Voice Clinic - St Mike's Hospital",
#     'location': {'address': 'Queen & Victoria',
#      'lat': 43.65370559692383,
#      'lng': -79.37797546386719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65370559692383,
#        'lng': -79.37797546386719}],
#      'distance': 480,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Queen & Victoria', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4cdf5495f8cdb1f738339112',
#     'name': "St Michael's Hospital Medical Imaging",
#     'location': {'address': '30 Bond St.',
#      'lat': 43.65368444376282,
#      'lng': -79.37870569300675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65368444376282,
#        'lng': -79.37870569300675}],
#      'distance': 421,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Bond St.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4dcda184b0fb25f6e32f4fe1',
#     'name': "St Micheal's Hospital Recovery",
#     'location': {'lat': 43.654817199405635,
#      'lng': -79.39034873504883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654817199405635,
#        'lng': -79.39034873504883}],
#      'distance': 537,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '5d23882e7ad19400231b8e60',
#     'name': 'St. Michael’s Hospital - Cardiology',
#     'location': {'lat': 43.652732,
#      'lng': -79.377305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652732,
#        'lng': -79.377305}],
#      'distance': 540,
#      'postalCode': 'M5C 1R5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5C 1R5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '57df138c498ec726bc83afad',
#     'name': 'St Michael Hospital Sculpture',
#     'location': {'lat': 43.653595,
#      'lng': -79.37713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653595,
#        'lng': -79.37713}],
#      'distance': 548,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ee',
#       'name': 'Street Art',
#       'pluralName': 'Street Art Installations',
#       'shortName': 'Street Art',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '5bec6350e179103c976b35be',
#     'name': 'St. Michael’s Hospital - Echocardiography',
#     'location': {'lat': 43.654114,
#      'lng': -79.377038,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654114,
#        'lng': -79.377038}],
#      'distance': 559,
#      'postalCode': 'M5B',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5B', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ed8e1f193ad464d269c9326',
#     'name': 'R. Fraser Elliot Building - Toronto General Hospital',
#     'location': {'address': '190 Elizabeth St, Toronto, ON M5G 2C4',
#      'lat': 43.65810949170471,
#      'lng': -79.3867585218272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65810949170471,
#        'lng': -79.3867585218272}],
#      'distance': 563,
#      'postalCode': 'M5G 2C4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['190 Elizabeth St, Toronto, ON M5G 2C4',
#       'Toronto ON M5G 2C4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '5836ec7a9900e6088c978dec',
#     'name': 'Helen Oelbaum Simpson Hospital Registration',
#     'location': {'lat': 43.657388,
#      'lng': -79.390382,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657388,
#        'lng': -79.390382}],
#      'distance': 677,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '54873b7f498efacad91a8b69',
#     'name': "St. Michael's Hospital - Paediatric Clinic",
#     'location': {'address': '61 Queen St. East',
#      'lat': 43.652965,
#      'lng': -79.376422,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652965,
#        'lng': -79.376422}],
#      'distance': 607,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['61 Queen St. East', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '5007e5dde4b0ba63820ebe1e',
#     'name': 'Mount Sinai Hospital - Room 548',
#     'location': {'lat': 43.657427,
#      'lng': -79.3893,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657427,
#        'lng': -79.3893}],
#      'distance': 616,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4f8499a5e4b07c5cea098474',
#     'name': 'CICU Toronto General Hospital',
#     'location': {'address': '190 Elizabeth Street',
#      'lat': 43.658716988295915,
#      'lng': -79.38677501623404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658716988295915,
#        'lng': -79.38677501623404}],
#      'distance': 626,
#      'postalCode': 'M5G 2C4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['190 Elizabeth Street',
#       'Toronto ON M5G 2C4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '53505398498e1727785471e1',
#     'name': 'Toronto General Hospital Cardiology Unit',
#     'location': {'lat': 43.658367,
#      'lng': -79.387957,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658367,
#        'lng': -79.387957}],
#      'distance': 633,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '53a9d10b498e3beb4d2580b1',
#     'name': "Sick Kids Hospital Farmer's Market",
#     'location': {'crossStreet': 'University Ave & Gerrard St.',
#      'lat': 43.657588,
#      'lng': -79.389321,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657588,
#        'lng': -79.389321}],
#      'distance': 630,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['University Ave & Gerrard St.',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b1c',
#       'name': 'Fruit & Vegetable Store',
#       'pluralName': 'Fruit & Vegetable Stores',
#       'shortName': 'Fruit & Vegetable Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4cee6f073b03f04d57f139dc',
#     'name': 'On the way cafe (mount sinai hospital)',
#     'location': {'address': '600 university Ave',
#      'lat': 43.65734371458051,
#      'lng': -79.39013431581283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65734371458051,
#        'lng': -79.39013431581283}],
#      'distance': 658,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['600 university Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4c0d4f6ad64c0f477284265d',
#     'name': 'Mt. Sinai Hospital PREPS Learning Centre',
#     'location': {'address': '600 University Ave',
#      'lat': 43.657738,
#      'lng': -79.390007,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657738,
#        'lng': -79.390007}],
#      'distance': 680,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['600 University Ave', 'Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '50070255e4b0b976338d221f',
#     'name': 'Mt Sinai Hospital Voice Clinic (Pathology)',
#     'location': {'address': '600 University Ave',
#      'crossStreet': "Queen's Park",
#      'lat': 43.657508850097656,
#      'lng': -79.39029693603516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657508850097656,
#        'lng': -79.39029693603516}],
#      'distance': 680,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["600 University Ave (Queen's Park)",
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '516eeef8498e01be6d9b842d',
#     'name': 'Hematology Clinic South (Princess Msrgaret Hospital)',
#     'location': {'address': '610 University Ave.',
#      'crossStreet': 'University & Murray St.',
#      'lat': 43.658671,
#      'lng': -79.390153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658671,
#        'lng': -79.390153}],
#      'distance': 764,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['610 University Ave. (University & Murray St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '512cbf65e4b0674c49016a24',
#     'name': 'Princess Margaret Hospital-Red Pod',
#     'location': {'lat': 43.658183,
#      'lng': -79.389962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658183,
#        'lng': -79.389962}],
#      'distance': 713,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '50c797b1e4b0c262e0d052f2',
#     'name': 'Princess Margaret Hospital- REACH Clinic',
#     'location': {'lat': 43.65791667887002,
#      'lng': -79.39049168093005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65791667887002,
#        'lng': -79.39049168093005}],
#      'distance': 722,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d194941735',
#       'name': 'Emergency Room',
#       'pluralName': 'Emergency Rooms',
#       'shortName': 'Emergency Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4ee201b9d5fbcceafebf2847',
#     'name': 'Sleep Medicine and Research Rounds at Toronto General Hospital',
#     'location': {'address': '200 Elizabeth St.',
#      'crossStreet': 'Ground Floor 025/026',
#      'lat': 43.65911684437622,
#      'lng': -79.3883228302002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65911684437622,
#        'lng': -79.3883228302002}],
#      'distance': 720,
#      'postalCode': 'M5G 2C4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Elizabeth St. (Ground Floor 025/026)',
#       'Toronto ON M5G 2C4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4e8f081946907a17cc4c5c20',
#     'name': 'Mount Sinai Hospital Special Pregnancy Program',
#     'location': {'lat': 43.658398642327136,
#      'lng': -79.38968348400323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658398642327136,
#        'lng': -79.38968348400323}],
#      'distance': 716,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '56eaa40a498eff8f02e378a0',
#     'name': 'Mount Sinai Hospital Food Court',
#     'location': {'lat': 43.65752,
#      'lng': -79.390493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65752,
#        'lng': -79.390493}],
#      'distance': 693,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4c915643b641236ad6b88079',
#     'name': 'Princess Margaret Hospital Parkade',
#     'location': {'lat': 43.65727451464682,
#      'lng': -79.39109095164324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65727451464682,
#        'lng': -79.39109095164324}],
#      'distance': 714,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4c066a088f8fa593023bf30d',
#     'name': 'Toronto General Hospital Pharmacy',
#     'location': {'address': '585 University Avenue',
#      'crossStreet': 'University and College',
#      'lat': 43.658353895355866,
#      'lng': -79.38978794522785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658353895355866,
#        'lng': -79.38978794522785}],
#      'distance': 718,
#      'postalCode': 'M5G',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['585 University Avenue (University and College)',
#       'Toronto ON M5G',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4e3bf091ae604542364fff91',
#     'name': 'Chemo Daycare (Princess Margaret Hospital)',
#     'location': {'address': '610 University Ave',
#      'lat': 43.658286286455564,
#      'lng': -79.39015630755222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658286286455564,
#        'lng': -79.39015630755222}],
#      'distance': 732,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['610 University Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '4e4ac4deb0fb37342ef36107',
#     'name': 'Ocular Oncology Clinic at Princess Margaret Hospital',
#     'location': {'address': '18th floor, 610 University Ave',
#      'lat': 43.65783070133404,
#      'lng': -79.39035423297143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65783070133404,
#        'lng': -79.39035423297143}],
#      'distance': 708,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18th floor, 610 University Ave',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False},
#    {'id': '5f33ef9e6419c108d227f55f',
#     'name': 'Princess Margaret Hospital - Yellow Pod',
#     'location': {'lat': 43.65814,
#      'lng': -79.391059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65814,
#        'lng': -79.391059}],
#      'distance': 773,
#      'postalCode': 'M5G 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5G 2M9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1612923160',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
#dataframe.shape
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                       name  \
# 0  4ad4c064f964a5206ef820e3  The Hospital for Sick Children (SickKids)
# 1  4ad4c064f964a5206ff820e3                     St. Michael's Hospital
# 2  4ad4c064f964a52070f820e3                   Toronto General Hospital
# 3  4af0615cf964a5208cdb21e3                   Women's College Hospital
# 4  4e3dd18362e19d6109746a06    Toronto General Hospital Emergency Room
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1612923160    False
# 1  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1612923160    False
# 2  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1612923160    False
# 3  [{'id': '4bf58dd8d48988d196941735', 'name': 'H...  v-1612923160    False
# 4  [{'id': '4bf58dd8d48988d194941735', 'name': 'E...  v-1612923160    False
#
#       location.address location.crossStreet  location.lat  location.lng  \
# 0  555 University Ave.       at Gerrard St.     43.657499    -79.386512
# 1           30 Bond St        at Queen St E     43.653784    -79.377809
# 2     190 Elizabeth St      at Gerrard St W     43.658762    -79.388292
# 3     76 Grenville St.           at Bay St.     43.661491    -79.387602
# 4     190 Elizabeth St      at Gerrard St W     43.658426    -79.386462
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65749866896264...                492
# 1  [{'label': 'display', 'lat': 43.65378419391942...                494
# 2  [{'label': 'display', 'lat': 43.65876218215914...                684
# 3  [{'label': 'display', 'lat': 43.66149084521543...                939
# 4  [{'label': 'display', 'lat': 43.65842614181627...                586
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1X8          CA       Toronto             ON
# 1             M5B 1W8          CA       Toronto             ON
# 2             M5G 2C4          CA       Toronto             ON
# 3             M5S 1B2          CA       Toronto             ON
# 4                 NaN          CA       Toronto             ON
#
#   location.country                          location.formattedAddress
# 0           Canada  [555 University Ave. (at Gerrard St.), Toronto...
# 1           Canada  [30 Bond St (at Queen St E), Toronto ON M5B 1W...
# 2           Canada  [190 Elizabeth St (at Gerrard St W), Toronto O...
# 3           Canada  [76 Grenville St. (at Bay St.), Toronto ON M5S...
# 4           Canada  [190 Elizabeth St (at Gerrard St W), Toronto O...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(49)
# Out:
#                                                  name  \
# 0           The Hospital for Sick Children (SickKids)
# 1                              St. Michael's Hospital
# 2                            Toronto General Hospital
# 3                            Women's College Hospital
# 4             Toronto General Hospital Emergency Room
# 5   Mount Sinai Hospital Women's and Infants' Depa...
# 6                            Toronto Western Hospital
# 7   Mount Sinai Hospital, Joseph and Wolf Lebovic ...
# 8                                        Hospital Row
# 9                                            Hospital
# 10               Toronto General Hospital Parking Lot
# 11                      Dundas Euclid Animal Hospital
# 12           St Michael's Hospital - Gastroenterology
# 13                         Bay Cat & Bay Dog Hospital
# 14                 Starbucks (St. Michael's Hospital)
# 15  St. Michael's Hospital - Glaucoma & Nerve Prot...
# 16          Inpatient Lounge - St. Michael's Hospital
# 17                               Mount Sinai Hospital
# 18                  MRI Department Sick Kids Hospital
# 19                              Rouge Valley Hospital
# 20                Endoscopy Unit St Michaels Hospital
# 21                 Gift Shop At St Michael's Hospital
# 22                                St Michael Hospital
# 23                  Voice Clinic - St Mike's Hospital
# 24              St Michael's Hospital Medical Imaging
# 25                     St Micheal's Hospital Recovery
# 26                St. Michael’s Hospital - Cardiology
# 27                      St Michael Hospital Sculpture
# 28          St. Michael’s Hospital - Echocardiography
# 29  R. Fraser Elliot Building - Toronto General Ho...
# 30        Helen Oelbaum Simpson Hospital Registration
# 31         St. Michael's Hospital - Paediatric Clinic
# 32                    Mount Sinai Hospital - Room 548
# 33                      CICU Toronto General Hospital
# 34           Toronto General Hospital Cardiology Unit
# 35                 Sick Kids Hospital Farmer's Market
# 36             On the way cafe (mount sinai hospital)
# 37           Mt. Sinai Hospital PREPS Learning Centre
# 38         Mt Sinai Hospital Voice Clinic (Pathology)
# 39  Hematology Clinic South (Princess Msrgaret Hos...
# 40                 Princess Margaret Hospital-Red Pod
# 41           Princess Margaret Hospital- REACH Clinic
# 42  Sleep Medicine and Research Rounds at Toronto ...
# 43     Mount Sinai Hospital Special Pregnancy Program
# 44                    Mount Sinai Hospital Food Court
# 45                 Princess Margaret Hospital Parkade
# 46                  Toronto General Hospital Pharmacy
# 47         Chemo Daycare (Princess Margaret Hospital)
# 48  Ocular Oncology Clinic at Princess Margaret Ho...
#
#                  categories  \
# 0                  Hospital
# 1                  Hospital
# 2                  Hospital
# 3                  Hospital
# 4            Emergency Room
# 5                  Hospital
# 6                  Hospital
# 7                  Hospital
# 8                      None
# 9            Medical School
# 10              Auto Garage
# 11                 Hospital
# 12                 Hospital
# 13             Veterinarian
# 14              Coffee Shop
# 15               Eye Doctor
# 16                 Hospital
# 17                 Hospital
# 18                 Hospital
# 19                 Hospital
# 20                 Hospital
# 21                Gift Shop
# 22                 Hospital
# 23                 Hospital
# 24           Medical Center
# 25                 Hospital
# 26                 Hospital
# 27               Street Art
# 28                 Hospital
# 29                 Hospital
# 30                 Hospital
# 31          Doctor's Office
# 32                 Hospital
# 33                 Hospital
# 34                 Hospital
# 35  Fruit & Vegetable Store
# 36                     Café
# 37                     None
# 38          Doctor's Office
# 39          Doctor's Office
# 40                 Hospital
# 41           Emergency Room
# 42                 Hospital
# 43                 Hospital
# 44               Food Court
# 45                  Parking
# 46                 Pharmacy
# 47                 Hospital
# 48           Medical Center
#
#                                               address  \
# 0                                 555 University Ave.
# 1                                          30 Bond St
# 2                                    190 Elizabeth St
# 3                                    76 Grenville St.
# 4                                    190 Elizabeth St
# 5   700 University Ave., 3rd floor, Ontario Power ...
# 6                                    399 Bathurst St.
# 7                                        60 Murray St
# 8                                                 NaN
# 9                                                 NaN
# 10                                   Elizabeth Street
# 11                                  840 Dundas St. W.
# 12                                                NaN
# 13                                         525 King E
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                 600 University Ave
# 18                                555 University Ave.
# 19                           580 Harwood Avenue Soith
# 20                                                NaN
# 21                                                NaN
# 22                                     50 Bond street
# 23                                   Queen & Victoria
# 24                                        30 Bond St.
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29              190 Elizabeth St, Toronto, ON M5G 2C4
# 30                                                NaN
# 31                                  61 Queen St. East
# 32                                                NaN
# 33                               190 Elizabeth Street
# 34                                                NaN
# 35                                                NaN
# 36                                 600 university Ave
# 37                                 600 University Ave
# 38                                 600 University Ave
# 39                                610 University Ave.
# 40                                                NaN
# 41                                                NaN
# 42                                  200 Elizabeth St.
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                              585 University Avenue
# 47                                 610 University Ave
# 48                     18th floor, 610 University Ave
#
#                      crossStreet        lat        lng  \
# 0                 at Gerrard St.  43.657499 -79.386512
# 1                  at Queen St E  43.653784 -79.377809
# 2                at Gerrard St W  43.658762 -79.388292
# 3                     at Bay St.  43.661491 -79.387602
# 4                at Gerrard St W  43.658426 -79.386462
# 5                 at College St.  43.659612 -79.390761
# 6             at Dundas St. West  43.653434 -79.406074
# 7           College & University  43.658247 -79.391473
# 8                            NaN  43.653939 -79.380815
# 9                            NaN  43.653190 -79.376370
# 10           College & Elizabeth  43.659780 -79.385699
# 11                        Euclid  43.651518 -79.409984
# 12                           NaN  43.653653 -79.378081
# 13                        Sumach  43.655346 -79.358770
# 14                           NaN  43.656193 -79.378846
# 15                           NaN  43.653703 -79.379490
# 16                           NaN  43.653428 -79.379383
# 17                           NaN  43.657701 -79.389711
# 18                           NaN  43.657149 -79.384323
# 19                           NaN  43.654843 -79.379067
# 20                           NaN  43.652371 -79.378923
# 21            Queen And Victoria  43.653947 -79.378483
# 22                           NaN  43.654024 -79.378736
# 23                           NaN  43.653706 -79.377975
# 24                           NaN  43.653684 -79.378706
# 25                           NaN  43.654817 -79.390349
# 26                           NaN  43.652732 -79.377305
# 27                           NaN  43.653595 -79.377130
# 28                           NaN  43.654114 -79.377038
# 29                           NaN  43.658109 -79.386759
# 30                           NaN  43.657388 -79.390382
# 31                           NaN  43.652965 -79.376422
# 32                           NaN  43.657427 -79.389300
# 33                           NaN  43.658717 -79.386775
# 34                           NaN  43.658367 -79.387957
# 35  University Ave & Gerrard St.  43.657588 -79.389321
# 36                           NaN  43.657344 -79.390134
# 37                           NaN  43.657738 -79.390007
# 38                  Queen's Park  43.657509 -79.390297
# 39       University & Murray St.  43.658671 -79.390153
# 40                           NaN  43.658183 -79.389962
# 41                           NaN  43.657917 -79.390492
# 42          Ground Floor 025/026  43.659117 -79.388323
# 43                           NaN  43.658399 -79.389683
# 44                           NaN  43.657520 -79.390493
# 45                           NaN  43.657275 -79.391091
# 46        University and College  43.658354 -79.389788
# 47                           NaN  43.658286 -79.390156
# 48                           NaN  43.657831 -79.390354
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 43.65749866896264...       492    M5G 1X8
# 1   [{'label': 'display', 'lat': 43.65378419391942...       494    M5B 1W8
# 2   [{'label': 'display', 'lat': 43.65876218215914...       684    M5G 2C4
# 3   [{'label': 'display', 'lat': 43.66149084521543...       939    M5S 1B2
# 4   [{'label': 'display', 'lat': 43.65842614181627...       586        NaN
# 5   [{'label': 'display', 'lat': 43.6596121502049,...       876        NaN
# 6   [{'label': 'display', 'lat': 43.65343431584569...      1783    M5T 2S7
# 7   [{'label': 'display', 'lat': 43.65824708835551...       806        NaN
# 8   [{'label': 'display', 'lat': 43.65393873543311...       256        NaN
# 9   [{'label': 'display', 'lat': 43.65319, 'lng': ...       610        M5C
# 10  [{'label': 'display', 'lat': 43.65978, 'lng': ...       715        NaN
# 11  [{'label': 'display', 'lat': 43.65151776470952...      2109    M6J 1V5
# 12  [{'label': 'display', 'lat': 43.653653, 'lng':...       471    M5B 1W8
# 13  [{'label': 'display', 'lat': 43.655346, 'lng':...      2037    M5A 1M3
# 14  [{'label': 'display', 'lat': 43.65619278670729...       508        NaN
# 15  [{'label': 'display', 'lat': 43.653703, 'lng':...       358        NaN
# 16  [{'label': 'display', 'lat': 43.653428, 'lng':...       366        NaN
# 17  [{'label': 'display', 'lat': 43.657701, 'lng':...       661    M5G 1X5
# 18  [{'label': 'display', 'lat': 43.65714939590222...       409        NaN
# 19  [{'label': 'display', 'lat': 43.6548432, 'lng'...       420        NaN
# 20  [{'label': 'display', 'lat': 43.65237139680637...       422        NaN
# 21  [{'label': 'display', 'lat': 43.65394745632515...       442        NaN
# 22  [{'label': 'display', 'lat': 43.65402368271969...       423        NaN
# 23  [{'label': 'display', 'lat': 43.65370559692383...       480        NaN
# 24  [{'label': 'display', 'lat': 43.65368444376282...       421        NaN
# 25  [{'label': 'display', 'lat': 43.65481719940563...       537        NaN
# 26  [{'label': 'display', 'lat': 43.652732, 'lng':...       540    M5C 1R5
# 27  [{'label': 'display', 'lat': 43.653595, 'lng':...       548        NaN
# 28  [{'label': 'display', 'lat': 43.654114, 'lng':...       559        M5B
# 29  [{'label': 'display', 'lat': 43.65810949170471...       563    M5G 2C4
# 30  [{'label': 'display', 'lat': 43.657388, 'lng':...       677        NaN
# 31  [{'label': 'display', 'lat': 43.652965, 'lng':...       607        NaN
# 32  [{'label': 'display', 'lat': 43.657427, 'lng':...       616        NaN
# 33  [{'label': 'display', 'lat': 43.65871698829591...       626    M5G 2C4
# 34  [{'label': 'display', 'lat': 43.658367, 'lng':...       633        NaN
# 35  [{'label': 'display', 'lat': 43.657588, 'lng':...       630        NaN
# 36  [{'label': 'display', 'lat': 43.65734371458051...       658        NaN
# 37  [{'label': 'display', 'lat': 43.657738, 'lng':...       680        NaN
# 38  [{'label': 'display', 'lat': 43.65750885009765...       680        NaN
# 39  [{'label': 'display', 'lat': 43.658671, 'lng':...       764        NaN
# 40  [{'label': 'display', 'lat': 43.658183, 'lng':...       713        NaN
# 41  [{'label': 'display', 'lat': 43.65791667887002...       722        NaN
# 42  [{'label': 'display', 'lat': 43.65911684437622...       720    M5G 2C4
# 43  [{'label': 'display', 'lat': 43.65839864232713...       716        NaN
# 44  [{'label': 'display', 'lat': 43.65752, 'lng': ...       693        NaN
# 45  [{'label': 'display', 'lat': 43.65727451464682...       714        NaN
# 46  [{'label': 'display', 'lat': 43.65835389535586...       718        M5G
# 47  [{'label': 'display', 'lat': 43.65828628645556...       732        NaN
# 48  [{'label': 'display', 'lat': 43.65783070133404...       708        NaN
#
#     cc     city state country  \
# 0   CA  Toronto    ON  Canada
# 1   CA  Toronto    ON  Canada
# 2   CA  Toronto    ON  Canada
# 3   CA  Toronto    ON  Canada
# 4   CA  Toronto    ON  Canada
# 5   CA  Toronto    ON  Canada
# 6   CA  Toronto    ON  Canada
# 7   CA  Toronto    ON  Canada
# 8   CA      NaN   NaN  Canada
# 9   CA  Toronto    ON  Canada
# 10  CA  Toronto    ON  Canada
# 11  CA  Toronto    ON  Canada
# 12  CA  Toronto    ON  Canada
# 13  CA  Toronto    ON  Canada
# 14  CA  Toronto    ON  Canada
# 15  CA      NaN   NaN  Canada
# 16  CA      NaN   NaN  Canada
# 17  CA  Toronto    ON  Canada
# 18  CA  Toronto    ON  Canada
# 19  CA     Ajax    ON  Canada
# 20  CA      NaN   NaN  Canada
# 21  CA  Toronto    ON  Canada
# 22  CA  Toronto    ON  Canada
# 23  CA  Toronto    ON  Canada
# 24  CA  Toronto    ON  Canada
# 25  CA  Toronto    ON  Canada
# 26  CA  Toronto    ON  Canada
# 27  CA      NaN   NaN  Canada
# 28  CA  Toronto    ON  Canada
# 29  CA  Toronto    ON  Canada
# 30  CA      NaN   NaN  Canada
# 31  CA  Toronto    ON  Canada
# 32  CA  Toronto    ON  Canada
# 33  CA  Toronto    ON  Canada
# 34  CA      NaN   NaN  Canada
# 35  CA  Toronto    ON  Canada
# 36  CA  Toronto    ON  Canada
# 37  CA  Toronto    ON  Canada
# 38  CA  Toronto    ON  Canada
# 39  CA  Toronto    ON  Canada
# 40  CA      NaN   NaN  Canada
# 41  CA      NaN   NaN  Canada
# 42  CA  Toronto    ON  Canada
# 43  CA  Toronto    ON  Canada
# 44  CA      NaN   NaN  Canada
# 45  CA  Toronto    ON  Canada
# 46  CA  Toronto    ON  Canada
# 47  CA  Toronto    ON  Canada
# 48  CA  Toronto    ON  Canada
#
#                                      formattedAddress  \
# 0   [555 University Ave. (at Gerrard St.), Toronto...
# 1   [30 Bond St (at Queen St E), Toronto ON M5B 1W...
# 2   [190 Elizabeth St (at Gerrard St W), Toronto O...
# 3   [76 Grenville St. (at Bay St.), Toronto ON M5S...
# 4   [190 Elizabeth St (at Gerrard St W), Toronto O...
# 5   [700 University Ave., 3rd floor, Ontario Power...
# 6   [399 Bathurst St. (at Dundas St. West), Toront...
# 7   [60 Murray St (College & University), Toronto ...
# 8                                            [Canada]
# 9                            [Toronto ON M5C, Canada]
# 10  [Elizabeth Street (College & Elizabeth), Toron...
# 11  [840 Dundas St. W. (Euclid), Toronto ON M6J 1V...
# 12                       [Toronto ON M5B 1W8, Canada]
# 13  [525 King E (Sumach), Toronto ON M5A 1M3, Canada]
# 14                               [Toronto ON, Canada]
# 15                                           [Canada]
# 16                                           [Canada]
# 17   [600 University Ave, Toronto ON M5G 1X5, Canada]
# 18          [555 University Ave., Toronto ON, Canada]
# 19        [580 Harwood Avenue Soith, Ajax ON, Canada]
# 20                                           [Canada]
# 21           [Queen And Victoria, Toronto ON, Canada]
# 22               [50 Bond street, Toronto ON, Canada]
# 23             [Queen & Victoria, Toronto ON, Canada]
# 24                  [30 Bond St., Toronto ON, Canada]
# 25                               [Toronto ON, Canada]
# 26                       [Toronto ON M5C 1R5, Canada]
# 27                                           [Canada]
# 28                           [Toronto ON M5B, Canada]
# 29  [190 Elizabeth St, Toronto, ON M5G 2C4, Toront...
# 30                                           [Canada]
# 31            [61 Queen St. East, Toronto ON, Canada]
# 32                               [Toronto ON, Canada]
# 33  [190 Elizabeth Street, Toronto ON M5G 2C4, Can...
# 34                                           [Canada]
# 35  [University Ave & Gerrard St., Toronto ON, Can...
# 36           [600 university Ave, Toronto ON, Canada]
# 37           [600 University Ave, Toronto ON, Canada]
# 38  [600 University Ave (Queen's Park), Toronto ON...
# 39  [610 University Ave. (University & Murray St.)...
# 40                                           [Canada]
# 41                                           [Canada]
# 42  [200 Elizabeth St. (Ground Floor 025/026), Tor...
# 43                               [Toronto ON, Canada]
# 44                                           [Canada]
# 45                               [Toronto ON, Canada]
# 46  [585 University Avenue (University and College...
# 47           [610 University Ave, Toronto ON, Canada]
# 48  [18th floor, 610 University Ave, Toronto ON, C...
#
#                           id
# 0   4ad4c064f964a5206ef820e3
# 1   4ad4c064f964a5206ff820e3
# 2   4ad4c064f964a52070f820e3
# 3   4af0615cf964a5208cdb21e3
# 4   4e3dd18362e19d6109746a06
# 5   4b1fbe8af964a5209e2824e3
# 6   4af2fb96f964a52086e921e3
# 7   4ae9bd8af964a520feb521e3
# 8   4fd8e916e4b0a8dbd1d82589
# 9   58cc204f45005e5834b89895
# 10  530e123911d277e2ae95c564
# 11  4bce159acc8cd13ac7b6c3cf
# 12  59525287c4df1d49b8a1e677
# 13  4c12aaf7a9c220a14d6a549d
# 14  4ec2d8502c5b1356c46f4248
# 15  5615508c498e81840497746b
# 16  4fca52d5e4b098b3ef28a713
# 17  4ad4c064f964a52071f820e3
# 18  52ab3cc6498e500543787648
# 19  4ec6412182311ff83c5a9e9b
# 20  4f4e40c2e4b082dc5ca9f9cf
# 21  4f09dee1e4b026656fae4626
# 22  4e5e3506fa768fe5f2c3ecc1
# 23  50d32905498ec019e3c227cf
# 24  4cdf5495f8cdb1f738339112
# 25  4dcda184b0fb25f6e32f4fe1
# 26  5d23882e7ad19400231b8e60
# 27  57df138c498ec726bc83afad
# 28  5bec6350e179103c976b35be
# 29  4ed8e1f193ad464d269c9326
# 30  5836ec7a9900e6088c978dec
# 31  54873b7f498efacad91a8b69
# 32  5007e5dde4b0ba63820ebe1e
# 33  4f8499a5e4b07c5cea098474
# 34  53505398498e1727785471e1
# 35  53a9d10b498e3beb4d2580b1
# 36  4cee6f073b03f04d57f139dc
# 37  4c0d4f6ad64c0f477284265d
# 38  50070255e4b0b976338d221f
# 39  516eeef8498e01be6d9b842d
# 40  512cbf65e4b0674c49016a24
# 41  50c797b1e4b0c262e0d052f2
# 42  4ee201b9d5fbcceafebf2847
# 43  4e8f081946907a17cc4c5c20
# 44  56eaa40a498eff8f02e378a0
# 45  4c915643b641236ad6b88079
# 46  4c066a088f8fa593023bf30d
# 47  4e3bf091ae604542364fff91
# 48  4e4ac4deb0fb37342ef36107

# %%
print (dataframe_filtered["categories"].value_counts())
print (dataframe_filtered["city"].value_counts())
# Out:
# Hospital                   29
# Doctor's Office             3
# Medical Center              2
# Emergency Room              2
# Parking                     1
# Pharmacy                    1
# Veterinarian                1
# Café                        1
# Coffee Shop                 1
# Fruit & Vegetable Store     1
# Food Court                  1
# Eye Doctor                  1
# Street Art                  1
# Auto Garage                 1
# Gift Shop                   1
# Medical School              1
# Name: categories, dtype: int64
# Toronto    39
# Ajax        1
# Name: city, dtype: int64

# %%
toronto_data = dataframe_filtered[["name","categories","lat","lng","city","id"]] 
toronto_data = toronto_data.fillna('')

#Data cleaning to get rid of unwanted categories and cities
toronto_data =toronto_data[toronto_data["categories"].str.contains("Hospital")].reset_index(drop=True)
toronto_data = toronto_data[~toronto_data.city.str.contains('a')]
toronto_data
# Out:
#                                                  name categories        lat  \
# 0           The Hospital for Sick Children (SickKids)   Hospital  43.657499
# 1                              St. Michael's Hospital   Hospital  43.653784
# 2                            Toronto General Hospital   Hospital  43.658762
# 3                            Women's College Hospital   Hospital  43.661491
# 4   Mount Sinai Hospital Women's and Infants' Depa...   Hospital  43.659612
# 5                            Toronto Western Hospital   Hospital  43.653434
# 6   Mount Sinai Hospital, Joseph and Wolf Lebovic ...   Hospital  43.658247
# 7                       Dundas Euclid Animal Hospital   Hospital  43.651518
# 8            St Michael's Hospital - Gastroenterology   Hospital  43.653653
# 9           Inpatient Lounge - St. Michael's Hospital   Hospital  43.653428
# 10                               Mount Sinai Hospital   Hospital  43.657701
# 11                  MRI Department Sick Kids Hospital   Hospital  43.657149
# 13                Endoscopy Unit St Michaels Hospital   Hospital  43.652371
# 14                                St Michael Hospital   Hospital  43.654024
# 15                  Voice Clinic - St Mike's Hospital   Hospital  43.653706
# 16                     St Micheal's Hospital Recovery   Hospital  43.654817
# 17                St. Michael’s Hospital - Cardiology   Hospital  43.652732
# 18          St. Michael’s Hospital - Echocardiography   Hospital  43.654114
# 19  R. Fraser Elliot Building - Toronto General Ho...   Hospital  43.658109
# 20        Helen Oelbaum Simpson Hospital Registration   Hospital  43.657388
# 21                    Mount Sinai Hospital - Room 548   Hospital  43.657427
# 22                      CICU Toronto General Hospital   Hospital  43.658717
# 23           Toronto General Hospital Cardiology Unit   Hospital  43.658367
# 24                 Princess Margaret Hospital-Red Pod   Hospital  43.658183
# 25  Sleep Medicine and Research Rounds at Toronto ...   Hospital  43.659117
# 26     Mount Sinai Hospital Special Pregnancy Program   Hospital  43.658399
# 27         Chemo Daycare (Princess Margaret Hospital)   Hospital  43.658286
# 28            Princess Margaret Hospital - Yellow Pod   Hospital  43.658140
#
#           lng     city                        id
# 0  -79.386512  Toronto  4ad4c064f964a5206ef820e3
# 1  -79.377809  Toronto  4ad4c064f964a5206ff820e3
# 2  -79.388292  Toronto  4ad4c064f964a52070f820e3
# 3  -79.387602  Toronto  4af0615cf964a5208cdb21e3
# 4  -79.390761  Toronto  4b1fbe8af964a5209e2824e3
# 5  -79.406074  Toronto  4af2fb96f964a52086e921e3
# 6  -79.391473  Toronto  4ae9bd8af964a520feb521e3
# 7  -79.409984  Toronto  4bce159acc8cd13ac7b6c3cf
# 8  -79.378081  Toronto  59525287c4df1d49b8a1e677
# 9  -79.379383           4fca52d5e4b098b3ef28a713
# 10 -79.389711  Toronto  4ad4c064f964a52071f820e3
# 11 -79.384323  Toronto  52ab3cc6498e500543787648
# 13 -79.378923           4f4e40c2e4b082dc5ca9f9cf
# 14 -79.378736  Toronto  4e5e3506fa768fe5f2c3ecc1
# 15 -79.377975  Toronto  50d32905498ec019e3c227cf
# 16 -79.390349  Toronto  4dcda184b0fb25f6e32f4fe1
# 17 -79.377305  Toronto  5d23882e7ad19400231b8e60
# 18 -79.377038  Toronto  5bec6350e179103c976b35be
# 19 -79.386759  Toronto  4ed8e1f193ad464d269c9326
# 20 -79.390382           5836ec7a9900e6088c978dec
# 21 -79.389300  Toronto  5007e5dde4b0ba63820ebe1e
# 22 -79.386775  Toronto  4f8499a5e4b07c5cea098474
# 23 -79.387957           53505398498e1727785471e1
# 24 -79.389962           512cbf65e4b0674c49016a24
# 25 -79.388323  Toronto  4ee201b9d5fbcceafebf2847
# 26 -79.389683  Toronto  4e8f081946907a17cc4c5c20
# 27 -79.390156  Toronto  4e3bf091ae604542364fff91
# 28 -79.391059  Toronto  5f33ef9e6419c108d227f55f

# %%
venues_map = folium.Map(location=[latitude1, longitude1], zoom_start=12) # generate map centred around Toronto
# add hospitals as red circle markers
for name, lat, lng, label in zip(toronto_data.name, toronto_data.lat, toronto_data.lng, toronto_data.categories):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a7435bee127144bbb4f2c3f49bff5561%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a7435bee127144bbb4f2c3f49bff5561%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a7435bee127144bbb4f2c3f49bff5561%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a7435bee127144bbb4f2c3f49bff5561%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
#   If you are not able to see the map, you may find a picture of it in the following link: https://raw.githubusercontent.com/verohy/Coursera_Capstone/master/Toronto_hospitals_Foursquare.png

# %% [markdown]
# ### Generating a new data base

# %% [markdown]
# A new data base is generated due to incongruencies with the CIHI information. Ratings and location from google and number of beds per hospital from the CIHI are added.

# %%
data={"name":["Baycrest","Casey House","Centre for Addiction and Mental Health","Holland Bloorview Kids Rehabilitation Hospital","Hospital for Sick Children","Michael Garron Hospital","Runnymede Healthcare Centre","Sinai Health System","Sunnybrook Health Sciences Centre","The Salvation Army Toronto Grace Health Centre","St. Joseph's Health Centre","St. Michael's Hospital","Toronto General Hospital","Toronto Western hospital","The Princess Margaret Cancer Centre","Toronto Rehabilitation Institute"],"Type of hospital":["Extended Care/Chronic, Rehabilitation, Psychiatric","Other","Psychiatric","Rehabilitation,Extended Care/Chronic","Pediatric","General","Extended Care/Chronic","General","General","Extended Care/Chronic,General","General","General","General","General","General","General"],"lat":["43.7300746225112","43.6693867285034","43.6428897749485","43.7213767933948","43.657499","43.6906452166705","43.6675445803748","43.657701","43.7253742521628","43.6711004049032","43.6483360510713","43.6581550382478","43.6591703311581","43.6534865436486","43.6585674749449","43.658967598333"],"long":["-79.4338938789395","-79.3769362272105","-79.4180492775939","-79.3534271285244","-79.386512","-79.3185044194517","-79.4736385042386","-79.389711","-79.3650557948233","-79.3804227182411","-79.4694012313738","-79.3254670824765","-79.3875968543474","-79.4041595665315","-79.3897135355979","-79.386235635609"],"borough":["North York","Downtown Toronto","West Toronto","East York","Downtown Toronto","East York","West Toronto","Downtown Toronto","Central Toronto","Downtown Toronto","West Toronto","Downtown Toronto","Downtown Toronto","Downtown Toronto","Downtown Toronto","Downtown Toronto"],"rating":["3.8","4.8","3.6","4.7","4.2","2.9","3.6","4.6","3.4","3.2","3","3.5","4.1","3.5","4.2","4.2"],"Other":["Research and teaching for the elderly","HIV/AIDS","Mental health teaching ","Children Rehabilitation","Children","","Rehabilitation and medically complex care","","","","Part of Unity Health Toronto","Part of Unity Health Toronto","Part of University Health Network","Part of University Health Network","Part of University Health Network","Part of University Health Network"],"beds":["262","13","495","63","263","367","206","732","1098","119","426","463","417","256","220",""]} 
new_toronto=pd.DataFrame(data)
new_toronto[['beds',"rating"]] = new_toronto[['beds',"rating"]].apply(pd.to_numeric) 
new_toronto
# Out:
#                                               name  \
# 0                                         Baycrest
# 1                                      Casey House
# 2           Centre for Addiction and Mental Health
# 3   Holland Bloorview Kids Rehabilitation Hospital
# 4                       Hospital for Sick Children
# 5                          Michael Garron Hospital
# 6                      Runnymede Healthcare Centre
# 7                              Sinai Health System
# 8                Sunnybrook Health Sciences Centre
# 9   The Salvation Army Toronto Grace Health Centre
# 10                      St. Joseph's Health Centre
# 11                          St. Michael's Hospital
# 12                        Toronto General Hospital
# 13                        Toronto Western hospital
# 14             The Princess Margaret Cancer Centre
# 15                Toronto Rehabilitation Institute
#
#                                      Type of hospital               lat  \
# 0   Extended Care/Chronic, Rehabilitation, Psychia...  43.7300746225112
# 1                                               Other  43.6693867285034
# 2                                         Psychiatric  43.6428897749485
# 3                Rehabilitation,Extended Care/Chronic  43.7213767933948
# 4                                           Pediatric         43.657499
# 5                                             General  43.6906452166705
# 6                               Extended Care/Chronic  43.6675445803748
# 7                                             General         43.657701
# 8                                             General  43.7253742521628
# 9                       Extended Care/Chronic,General  43.6711004049032
# 10                                            General  43.6483360510713
# 11                                            General  43.6581550382478
# 12                                            General  43.6591703311581
# 13                                            General  43.6534865436486
# 14                                            General  43.6585674749449
# 15                                            General   43.658967598333
#
#                  long           borough  rating  \
# 0   -79.4338938789395        North York     3.8
# 1   -79.3769362272105  Downtown Toronto     4.8
# 2   -79.4180492775939      West Toronto     3.6
# 3   -79.3534271285244         East York     4.7
# 4          -79.386512  Downtown Toronto     4.2
# 5   -79.3185044194517         East York     2.9
# 6   -79.4736385042386      West Toronto     3.6
# 7          -79.389711  Downtown Toronto     4.6
# 8   -79.3650557948233   Central Toronto     3.4
# 9   -79.3804227182411  Downtown Toronto     3.2
# 10  -79.4694012313738      West Toronto     3.0
# 11  -79.3254670824765  Downtown Toronto     3.5
# 12  -79.3875968543474  Downtown Toronto     4.1
# 13  -79.4041595665315  Downtown Toronto     3.5
# 14  -79.3897135355979  Downtown Toronto     4.2
# 15   -79.386235635609  Downtown Toronto     4.2
#
#                                         Other    beds
# 0       Research and teaching for the elderly   262.0
# 1                                    HIV/AIDS    13.0
# 2                     Mental health teaching    495.0
# 3                     Children Rehabilitation    63.0
# 4                                    Children   263.0
# 5                                               367.0
# 6   Rehabilitation and medically complex care   206.0
# 7                                               732.0
# 8                                              1098.0
# 9                                               119.0
# 10               Part of Unity Health Toronto   426.0
# 11               Part of Unity Health Toronto   463.0
# 12          Part of University Health Network   417.0
# 13          Part of University Health Network   256.0
# 14          Part of University Health Network   220.0
# 15          Part of University Health Network     NaN

# %%
hospitals_map = folium.Map(location=[latitude1, longitude1], zoom_start=12) # generate map centred around Toronto
# add hospitals as red circle markers
for name, lat, lng, bor, rat in zip(new_toronto.name, new_toronto.lat, new_toronto.long, new_toronto.borough, new_toronto.rating):
    label = 'Name: {}, Borough: {}, Rating: {}'.format(name,bor,rat)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='white',
        fill_opacity=0.6
    ).add_to(hospitals_map)

# display map
hospitals_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a3281c72e32f420aa9ba3373d9f775ee%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a3281c72e32f420aa9ba3373d9f775ee%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a3281c72e32f420aa9ba3373d9f775ee%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a3281c72e32f420aa9ba3373d9f775ee%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
#   If you are not able to see the map, you may find a picture of it in the following link: https://raw.githubusercontent.com/verohy/Coursera_Capstone/master/Toronto_hospitals_CIHI.png

# %% [markdown]
# In order to compare the boroughs, the zones will be clustered to understand how the facilities are distributed

# %%
from folium import plugins

hospitals_map = folium.Map(location = [latitude1, longitude1], zoom_start = 12)

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(hospitals_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label in zip(new_toronto.lat, new_toronto.long, new_toronto.name):
    folium.Marker(
        location=[lat, lng],
        icon=folium.Icon(color='red',icon='plus'),
        popup=label,
    ).add_to(incidents)

# display map
hospitals_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4d545e31f1b04ba4a3a474871ff39ae0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4d545e31f1b04ba4a3a474871ff39ae0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# If you are not able to see the map, you can find a picture of it in the following link:
#     1. Zoom = 9: https://raw.githubusercontent.com/verohy/Coursera_Capstone/master/Toronto_cluster_zoom9.png
#     2. Zoom = 12: https://raw.githubusercontent.com/verohy/Coursera_Capstone/master/Toronto_cluster_zoom12.png

# %% [markdown]
# To elaborate the conclusion the new data base is summerized in the following charts:

# %% [markdown]
# ### 1. Chart Boroughs ordered by number of hospital beds

# %%
summerize = new_toronto.groupby("borough").agg({"beds":"sum","name":"count","rating":"mean"})
summerize = summerize.sort_values(by=["beds"],ascending=False)
summerize = summerize.rename(columns={"beds":"Number of beds","name":"Number of hospitals","rating":"Rating Average" })
summerize.head()
# Out:
#                   Number of beds  Number of hospitals  Rating Average
# borough
# Downtown Toronto          2483.0                    9        4.033333
# West Toronto              1127.0                    3        3.400000
# Central Toronto           1098.0                    1        3.400000
# East York                  430.0                    2        3.800000
# North York                 262.0                    1        3.800000

# %% [markdown]
# ### 2. Chart Top Hospital per borough and its rating

# %%
rating=new_toronto[["borough","name","rating"]].sort_values(by=["rating"],ascending=False)
rating=rating.groupby("borough").agg({"name":"first","rating":"max"})
rating=rating.sort_values(by=["rating"],ascending=False)
rating=rating.rename(columns={"rating":"Top 1 Hospital Rating","name":"Top 1 Hospital"})
rating
# Out:
#                                                   Top 1 Hospital  \
# borough
# Downtown Toronto                                     Casey House
# East York         Holland Bloorview Kids Rehabilitation Hospital
# North York                                              Baycrest
# West Toronto              Centre for Addiction and Mental Health
# Central Toronto                Sunnybrook Health Sciences Centre
#
#                   Top 1 Hospital Rating
# borough
# Downtown Toronto                    4.8
# East York                           4.7
# North York                          3.8
# West Toronto                        3.6
# Central Toronto                     3.4

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We can conclude through the map and the number of beds per borough that Downtown Toronto is by far the most dense in hospitals and medicals beds followed by West, Central and the York's boroughs. As for the ratings, Downtown Toronto has the best rated with "Casey House" and the best average as well, followed closely by East York with the "Holland Bloorview Kids Rehabilitation Hospital" and the same average rating of 3.8 as North York.
